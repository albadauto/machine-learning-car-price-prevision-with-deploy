# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# df_price_car = pd.read_csv('dataset/car_price.csv')

# %%
df_price_car = pd.read_csv('dataset/car_price.csv', index_col=False)

# %%
df_price_car.head()
# Out:
#                     CarName      carbody drivewheel enginelocation fueltype  \
# 0        alfa-romero giulia  convertible        rwd          front      gas
# 1       alfa-romero stelvio  convertible        rwd          front      gas
# 2  alfa-romero Quadrifoglio    hatchback        rwd          front      gas
# 3               audi 100 ls        sedan        fwd          front      gas
# 4                audi 100ls        sedan        4wd          front      gas
#
#   aspiration doornumber cylindernumber enginetype fuelsystem  ...  curbweight  \
# 0        std        two           four       dohc       mpfi  ...        2548
# 1        std        two           four       dohc       mpfi  ...        2548
# 2        std        two            six       ohcv       mpfi  ...        2823
# 3        std       four           four        ohc       mpfi  ...        2337
# 4        std       four           five        ohc       mpfi  ...        2824
#
# ...

# %%
df_price_car_new = pd.DataFrame({
   "carbody": df_price_car['carbody'], 
    "price": df_price_car['price'], 
    "horsepower": df_price_car['horsepower'], 
    "enginesize": df_price_car['enginesize']
})

# %%
df_price_car_new
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_price_car_new['carbody'] = encoder.fit_transform(df_price_car_new['carbody'])

# %%
sns.heatmap(df_price_car_new, annot=True, linewidths=(0.5))
# Out:
# <Axes: >
